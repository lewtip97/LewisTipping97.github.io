# %%
import geopandas as gpd
gdf = gpd.read_file("data/prow/ldnpa_prow.geojson")
print(gdf.head())
print(gdf.crs)
print(len(gdf), "features")
# Out:
#   NUMBER_ Type_Text                                           geometry
# 0  206044        FP  LINESTRING (-3.17833 54.65946, -3.17845 54.659...
# 1  201066        FP  LINESTRING (-3.23038 54.57570, -3.23053 54.575...
# 2  201110        FP  LINESTRING (-3.25542 54.57889, -3.25543 54.578...
# 3  201074        FP  LINESTRING (-3.25905 54.58505, -3.25902 54.585...
# 4  212066        FP  LINESTRING (-3.15915 54.56378, -3.15867 54.563...
# epsg:4326
# 2938 features
